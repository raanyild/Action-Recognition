# %%
#label 1 for pouring
for i in range(10, 41):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(130, 156):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(165, 189):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(197, 217):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(228, 243):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(373, 392):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(434, 461):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(467, 491):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(500, 521):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(532, 555):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(567, 596):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(710, 739):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(762, 791):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()
for i in range(905, 922):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("1")
    f.close()

# %%
#label 2 for stirring
for i in range(55, 86):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("2")
    f.close()
for i in range(268, 304):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("2")
    f.close()
for i in range(305, 324):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("2")
    f.close()
for i in range(618, 654):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("2")
    f.close()
for i in range(810, 867):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("2")
    f.close()
for i in range(939, 971):
    path = "labels/"
    path += str(i) + ".txt"
    f = open(path, "w")
    f.write("2")
    f.close()

# %%
import os
#label 0 for no action
for i in range(1021):
    path_f = "labels/"
    path_f += str(i) + ".txt"
    if not os.path.isfile(path_f):
        f = open(path_f, "w")
        f.write("0")
        f.close()
